# %%
# %matplotlib inline
import matplotlib.pyplot as plt
#from datetime import datetime
import os
#import requests
import pandas as pd
#import numpy as np
import xarray as xr
#import datetime
import warnings
warnings.simplefilter("ignore", category=RuntimeWarning)

filepath = './../../imerg/imerg'

# %%
#combine all files in year into a single file
istart=0
for year in range(2023,2025):
    for day in range(1, 366):  
        file_name = filepath+str(year)+str(day)+'.nc'
        if not(os.path.exists(file_name)):
            continue
        #print(file_name)
        ds_ts=xr.open_dataset(file_name)
        if istart==0:
            ds_ts2 = ds_ts
            istart=1
        else:
            ds_ts2 = xr.concat([ds_ts2,ds_ts],dim='time')
        ds_ts.close()    
file_output_name = filepath+str(year)+'_all.nc'
ds_ts2.to_netcdf(file_output_name)
df = ds_ts2.to_dataframe()
df = df.drop(columns=['lon','lat'])
file_output_name = filepath+'_all.csv'
df.to_csv(file_output_name)
print('output',file_output_name)
# Out:
# output ./../../imerg/imerg_all.csv

# %%
ds_ts2.precipitation.plot()
